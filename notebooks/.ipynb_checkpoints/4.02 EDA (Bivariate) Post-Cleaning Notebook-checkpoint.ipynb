# %% [markdown]
# <div style="text-align: right"> Tommy Evans-Barton </div>
# <div style="text-align: right"> WR Year 2 Jumps </div>
#
# # EDA (Bivariate) Post-Cleaning Notebook
#
# This notebook will be analyzing the data after it's transformation and cleaning in order to better inform the model that will be built in the analysis, specifically conducting bivariate analyses of the relations between different modeling variables. It is important to have a good understanding of the data being fed into a model before building said model.

# %%
import os
import sys
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats

# %%
# %load_ext autoreload
# %autoreload 2

# %%
TOP_PATH = os.environ['PWD']

# %%
sys.path.append(TOP_PATH + '/src')
sys.path.append(TOP_PATH + '/src/viz')

# %%
import eda_viz_post

# %%
df = pd.read_csv(TOP_PATH + '/data/final/FINAL_DATA.csv')
df_model = df[df['First Year'] < 2019].reset_index(drop = True)
df_predict = df[df['First Year'] == 2019].reset_index(drop = True)

# %%
for c in df_model.columns:
    fig = plt.figure()
    plt.scatter(df_model[c], df_model['Rec Pts/G Second Season'])
    plt.xlabel(c)
    plt.show()

# %%
df_model[df_model['WR Yds Share'] > .6]
# Out:
#     Rnd  Pick Team  Player  First Year  Age Draft     G    GS    Tgt  \
# 17    1    23  KAN  D.Bowe        2007         22  16.0  15.0  116.0
#
#     WR Tgt Share  ...  Projected Rec Share  Projected Rec  \
# 17       0.63388  ...             0.893491       95.60355
#
#     Projected Yds Share  Projected Yds  Projected TD Share  Projected TD  \
# 17             0.832305     1160.23251               0.625         4.375
#
#     Rec Pts First Season  Rec Pts/G First Season  Rec Pts Second Season  \
# 17                 129.5                 8.09375                  144.2
#
#     Rec Pts/G Second Season
# 17                   9.0125
#
# [1 rows x 42 columns]

# %%
plt.scatter(df_model['G'], df_model['Rec Pts/G Second Season'])
