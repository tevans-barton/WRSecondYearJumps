# %% [markdown]
# <div style="text-align: right"> Tommy Evans-Barton </div>
# <div style="text-align: right"> WR Year 2 Jumps </div>
#
# # Analysis and Modeling Notebook
#
# The purpose of this notebook is to develop the model used to predict second year production for receivers based on their statistics in their first year. This notebook will also serve as a preliminary 'final notebook' before the final presentation of this project's findings.

# %%
import os
import sys
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Binarizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
import seaborn as sns
import scipy.stats
from scipy.optimize import minimize

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
TOP_PATH = os.environ['PWD']

# %% [markdown]
# ## Reading in Data

# %%
df = pd.read_csv(TOP_PATH + '/data/final/FINAL_DATA.csv')
df
# Out:
#      Rnd  Pick Team              Player  First Year  Age Draft     G    GS  \
# 0      1     3  CLE           B.Edwards        2005         22  10.0   7.0
# 1      1     7  MIN        T.Williamson        2005         22  14.0   3.0
# 2      1    10  DET          M.Williams        2005         21  14.0   4.0
# 3      1    21  JAX             M.Jones        2005         22  16.0   1.0
# 4      1    22  BAL           M.Clayton        2005         23  14.0  10.0
# ..   ...   ...  ...                 ...         ...        ...   ...   ...
# 126    2    57  PHI  J.Arcega-Whiteside        2019         22  16.0   5.0
# 127    2    64  SEA           D.Metcalf        2019         21  16.0  15.0
# 128    3    66  PIT           D.Johnson        2019         23  16.0  12.0
# 129    3    76  WAS          T.McLaurin        2019         23  14.0  14.0
# 130    3    93  BAL            M.Boykin        2019         22  16.0  11.0
#
#        Tgt  WR Tgt Share  ...  Projected Rec Share  Projected Rec  \
# 0     59.0      0.226923  ...             0.425007      61.201005
# 1     52.0      0.180556  ...             0.484076      76.000000
# 2     57.0      0.256757  ...             0.381579      43.500000
# 3     69.0      0.206587  ...             0.582418     106.000000
# 4     87.0      0.388393  ...             0.338462      44.000000
# ..     ...           ...  ...                  ...            ...
# 126   22.0      0.126437  ...             0.485149      49.000000
# 127  100.0      0.375940  ...             0.424419      73.000000
# 128   92.0      0.380165  ...             0.406897      59.000000
# 129   93.0      0.505435  ...             0.508772      58.000000
# 130   22.0      0.122905  ...             0.298246      34.000000
#
#      Projected Yds Share  Projected Yds  Projected TD Share  Projected TD  \
# 0               0.498598     981.739542            0.222222           2.0
# 1               0.483380    1047.000000            0.307692           4.0
# 2               0.257708     374.707921           -0.444444          -4.0
# 3               0.563735    1455.000000            0.611111          11.0
# 4               0.305052     471.000000            0.400000           2.0
# ..                   ...            ...                 ...           ...
# 126             0.450466     532.000000            0.400000           4.0
# 127             0.457451    1145.000000            0.444444           8.0
# 128             0.345704     680.000000            0.454545           5.0
# 129             0.620108     919.000000            0.875000           7.0
# 130             0.331918     469.000000            0.294118           5.0
#
#      Rec Pts First Season  Rec Pts/G First Season  Rec Pts Second Season  \
# 0                    69.2                6.920000                  124.4
# 1                    49.2                3.514286                   45.5
# 2                    41.0                2.928571                   15.9
# 3                    73.2                4.575000                   88.3
# 4                    59.1                4.221429                  123.9
# ..                    ...                     ...                    ...
# 126                  22.9                1.431250                    NaN
# 127                 132.0                8.250000                    NaN
# 128                  98.0                6.125000                    NaN
# 129                 133.9                9.564286                    NaN
# 130                  37.8                2.362500                    NaN
#
#      Rec Pts/G Second Season
# 0                   7.775000
# 1                   3.250000
# 2                   1.987500
# 3                   6.307143
# 4                   7.743750
# ..                       ...
# 126                      NaN
# 127                      NaN
# 128                      NaN
# 129                      NaN
# 130                      NaN
#
# [131 rows x 42 columns]

# %%
df_model = df[df['First Year'] < 2019].reset_index(drop = True)
df_prediction = df[df['First Year'] == 2019].reset_index(drop = True)

# %%
df_model
# Out:
#      Rnd  Pick Team        Player  First Year  Age Draft     G    GS   Tgt  \
# 0      1     3  CLE     B.Edwards        2005         22  10.0   7.0  59.0
# 1      1     7  MIN  T.Williamson        2005         22  14.0   3.0  52.0
# 2      1    10  DET    M.Williams        2005         21  14.0   4.0  57.0
# 3      1    21  JAX       M.Jones        2005         22  16.0   1.0  69.0
# 4      1    22  BAL     M.Clayton        2005         23  14.0  10.0  87.0
# ..   ...   ...  ...           ...         ...        ...   ...   ...   ...
# 116    2    51  CHI      A.Miller        2018         23  15.0   4.0  54.0
# 117    2    60  PIT  J.Washington        2018         22  14.0   6.0  38.0
# 118    2    61  JAX       D.Chark        2018         21  11.0   0.0  32.0
# 119    3    81  DAL      M.Gallup        2018         22  16.0   8.0  68.0
# 120    3    91  NOR       T.Smith        2018         22  15.0   7.0  44.0
#
#      WR Tgt Share  ...  Projected Rec Share  Projected Rec  \
# 0        0.226923  ...             0.425007      61.201005
# 1        0.180556  ...             0.484076      76.000000
# 2        0.256757  ...             0.381579      43.500000
# 3        0.206587  ...             0.582418     106.000000
# 4        0.388393  ...             0.338462      44.000000
# ..            ...  ...                  ...            ...
# 116      0.192171  ...             0.544404      98.537037
# 117      0.094763  ...             0.550607     136.000000
# 118      0.109589  ...             0.208546      34.618557
# 119      0.311927  ...             0.787760     107.923077
# 120      0.159420  ...             0.256039      53.000000
#
#      Projected Yds Share  Projected Yds  Projected TD Share  Projected TD  \
# 0               0.498598     981.739542            0.222222      2.000000
# 1               0.483380    1047.000000            0.307692      4.000000
# 2               0.257708     374.707921           -0.444444     -4.000000
# 3               0.563735    1455.000000            0.611111     11.000000
# 4               0.305052     471.000000            0.400000      2.000000
# ..                   ...            ...                 ...           ...
# 116             0.495570    1036.732673            0.533333      8.000000
# 117             0.532306    1623.000000            0.695652     16.000000
# 118             0.291061     596.675743            0.148148      1.333333
# 119             0.795709    1346.339575            0.677778      6.100000
# 120             0.320792     810.000000            0.409091      9.000000
#
#      Rec Pts First Season  Rec Pts/G First Season  Rec Pts Second Season  \
# 0                    69.2                6.920000                  124.4
# 1                    49.2                3.514286                   45.5
# 2                    41.0                2.928571                   15.9
# 3                    73.2                4.575000                   88.3
# 4                    59.1                4.221429                  123.9
# ..                    ...                     ...                    ...
# 116                  84.3                5.620000                   77.6
# 117                  27.7                1.978571                   91.5
# 118                  17.4                1.581818                  148.8
# 119                  62.7                3.918750                  146.7
# 120                  72.7                4.846667                   53.4
#
#      Rec Pts/G Second Season
# 0                   7.775000
# 1                   3.250000
# 2                   1.987500
# 3                   6.307143
# 4                   7.743750
# ..                       ...
# 116                 4.850000
# 117                 6.100000
# 118                 9.920000
# 119                10.478571
# 120                 4.854545
#
# [121 rows x 42 columns]

# %%
df_prediction
# Out:
#    Rnd  Pick Team              Player  First Year  Age Draft     G    GS  \
# 0    1    25  BAL             M.Brown        2019         22  14.0  11.0
# 1    1    32  NWE             N.Harry        2019         21   7.0   5.0
# 2    2    36  SFO            D.Samuel        2019         23  15.0  11.0
# 3    2    51  TEN             A.Brown        2019         22  16.0  11.0
# 4    2    56  KAN           M.Hardman        2019         21  16.0   5.0
# 5    2    57  PHI  J.Arcega-Whiteside        2019         22  16.0   5.0
# 6    2    64  SEA           D.Metcalf        2019         21  16.0  15.0
# 7    3    66  PIT           D.Johnson        2019         23  16.0  12.0
# 8    3    76  WAS          T.McLaurin        2019         23  14.0  14.0
# 9    3    93  BAL            M.Boykin        2019         22  16.0  11.0
#
#      Tgt  WR Tgt Share  ...  Projected Rec Share  Projected Rec  \
# 0   71.0      0.396648  ...             0.587719      67.000000
# 1   24.0      0.129730  ...             0.089364      10.366197
# 2   81.0      0.476471  ...             0.458549      50.440367
# 3   84.0      0.350000  ...             0.492268      78.270642
# 4   41.0      0.149091  ...             0.154762      26.000000
# 5   22.0      0.126437  ...             0.485149      49.000000
# 6  100.0      0.375940  ...             0.424419      73.000000
# 7   92.0      0.380165  ...             0.406897      59.000000
# 8   93.0      0.505435  ...             0.508772      58.000000
# 9   22.0      0.122905  ...             0.298246      34.000000
#
#    Projected Yds Share  Projected Yds  Projected TD Share  Projected TD  \
# 0             0.605096     855.000000            0.529412      9.000000
# 1             0.075781      96.848335            0.222222      2.000000
# 2             0.498320     725.054975            0.217172      2.388889
# 3             0.587432    1393.388276            0.750000     12.000000
# 4             0.213492     538.000000            0.300000      6.000000
# 5             0.450466     532.000000            0.400000      4.000000
# 6             0.457451    1145.000000            0.444444      8.000000
# 7             0.345704     680.000000            0.454545      5.000000
# 8             0.620108     919.000000            0.875000      7.000000
# 9             0.331918     469.000000            0.294118      5.000000
#
#    Rec Pts First Season  Rec Pts/G First Season  Rec Pts Second Season  \
# 0                 100.4                7.171429                    NaN
# 1                  22.5                3.214286                    NaN
# 2                  98.2                6.546667                    NaN
# 3                 153.1                9.568750                    NaN
# 4                  89.8                5.612500                    NaN
# 5                  22.9                1.431250                    NaN
# 6                 132.0                8.250000                    NaN
# 7                  98.0                6.125000                    NaN
# 8                 133.9                9.564286                    NaN
# 9                  37.8                2.362500                    NaN
#
#    Rec Pts/G Second Season
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
#
# [10 rows x 42 columns]

# %%
X_temp, X_test, y_temp, y_test = train_test_split(df_model.drop(['Rec Pts Second Season', 'Rec Pts/G Second Season'], axis = 1), df_model['Rec Pts/G Second Season'], test_size = 0.2, random_state = 1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_temp, y_temp, test_size = 0.2, random_state = 1)

# %%
X_train = X_train.reset_index(drop = True)
X_valid = X_valid.reset_index(drop = True)
X_test = X_test.reset_index(drop = True)
y_train = y_train.reset_index(drop = True)
y_valid = y_valid.reset_index(drop = True)
y_test = y_test.reset_index(drop = True)

# %%
def median_abs_error(y_pred, y_true):
    y_pred = np.array(y_pred)
    y_true = np.array(y_true)
    return np.median(abs(y_true - y_pred))

# %%
cat_feat = ['Rnd', 'Age Draft']

cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(categories = 'auto'))     # categorical columns become input to OneHot
])

reg_num_feat = ['Pick', 'First Year', 'Age Draft', 'G', 'GS',
        'Tgt', 'Catch Rate', 'Y/R', 'TD', 'WR TD Share', 'Lng', 'Y/Tgt', 'Y/G', 
        'Projected Tgt Share', 'Projected Tgt', 'Projected Rec Share', 'Projected Rec', 'Projected Yds Share',
        'Projected Yds', 'Projected TD Share', 'Projected TD']
sqrt_num_feat = ['WR Tgt Share', 'Rec', 'WR Rec Share', 'Yds', 'WR Yds Share', '1D', 
                 'R/G', 'EYds', 'Rec Pts First Season', 'Rec Pts/G First Season']
adv_num_feat = ['DYAR', 'YAR', 'DVOA', 'VOA', 'DPI Pens', 'DPI Yds']
num_feat = reg_num_feat + sqrt_num_feat + adv_num_feat

sqrt_transformer = Pipeline(steps = [
    ('sqrt', FunctionTransformer(lambda x : x**.5))
])

num_transformer = Pipeline(steps=[
    ('none', FunctionTransformer(lambda x : x))
])

small_selection = ['Tgt', 'TD', 'Rec Pts/G First Season']
small_sqrt = ['Rec', 'Yds', '1D', 'EYds']

preproc1 = ColumnTransformer(transformers=[('sqrt', sqrt_transformer, small_sqrt), ('none', num_transformer, small_selection), ('cat', cat_transformer, cat_feat)])

pl = Pipeline(steps=[('preprocessor', preproc1), ('regressor', LinearRegression(normalize = True))])

# %%
pl.fit(X_train[small_selection + small_sqrt + cat_feat], y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('sqrt',
#                                                   Pipeline(memory=None,
#                                                            steps=[('sqrt',
#                                                                    FunctionTransformer(accept_sparse=False,
#                                                                                        check_inverse=True,
#                                                                                        func=<function <lambda> at 0x7fb3cf10e8c0>,
#                                                                                        inv_kw_args=None,
#                                                                                        inverse_func=None,
#                                                                                        kw_args=None,
#                                                                                        pass_y='...
#                                                  ('cat',
#                                                   Pipeline(memory=None,
#                                                            steps=[('onehot',
#                                                                    OneHotEncoder(categorical_features=None,
#                                                                                  categories='auto',
#                                                                                  drop=None,
#                                                                                  dtype=<class 'numpy.float64'>,
#                                                                                  handle_unknown='error',
#                                                                                  n_values=None,
#                                                                                  sparse=True))],
#                                                            verbose=False),
#                                                   ['Rnd', 'Age Draft'])],
#                                    verbose=False)),
#                 ('regressor',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=True))],
#          verbose=False)

# %%
pd.DataFrame(zip(small_selection + small_sqrt + ['Rnd1', 'Rnd2', 'Rnd3'] + list(set(df_model['Age Draft'])), pl.named_steps['regressor'].coef_))
# Out:
#                          0         1
# 0                      Tgt -1.615440
# 1                       TD  0.238108
# 2   Rec Pts/G First Season  1.042715
# 3                      Rec  0.113606
# 4                      Yds -0.009792
# 5                       1D -0.506336
# 6                     EYds  0.882820
# 7                     Rnd1  0.490175
# 8                     Rnd2  0.233418
# 9                     Rnd3 -0.872251
# 10                      20  1.142552
# 11                      21  0.080882
# 12                      22 -0.226394
# 13                      23 -0.483542
# 14                      24  1.519432

# %%
valid_pred = pl.predict(X_valid[small_selection + small_sqrt + ['Rnd', 'Age Draft']])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)

# %%
train_pred = pl.predict(X_train[small_selection + small_sqrt + ['Rnd', 'Age Draft']])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)

# %%
valid_pred
# Out:
# array([ 4.47365711,  5.12759497,  2.43119708,  7.05624141,  0.35267438,
#         9.92278893,  4.97386018,  6.98118712, 10.78826982,  6.64885556,
#         6.15819328,  6.12324515,  3.85202452,  9.20398873,  8.04781957,
#         9.29717597,  4.92228206,  6.5376725 ,  6.75998294,  8.95569642])

# %%
temp = X_valid.copy()
temp['Actual'] = y_valid
temp['Prediction'] = valid_pred

# %%
temp_train = X_train.copy()
temp_train['Actual'] = y_train
temp_train['Prediction'] = train_pred

# %%
#Validation Error
np.sqrt(np.mean((y_valid - valid_pred) ** 2))
# Out:
# 2.059613971758222

# %%
#Training Error
np.sqrt(np.mean((y_train - train_pred) ** 2))
# Out:
# 2.1381957301396137

# %%
temp['Absolute Error'] = np.abs(valid_pred - y_valid)

# %%
temp['Error'] = (valid_pred - y_valid)

# %%
temp.sort_values('Absolute Error')
# Out:
#     Rnd  Pick Team        Player  First Year  Age Draft     G    GS    Tgt  \
# 7     3    74  DAL    T.Williams        2013         23  16.0   8.0   74.0
# 6     2    51  CHI      A.Miller        2018         23  15.0   4.0   54.0
# 17    2    44  DET       T.Young        2011         22  16.0   9.0   86.0
# 19    1    24  CAR       D.Moore        2018         21  16.0  10.0   82.0
# 0     2    36  GNB      J.Nelson        2008         23  16.0   2.0   54.0
# 14    2    42  PHI    J.Matthews        2014         22  16.0  10.0  103.0
# 15    1    20  NOR       B.Cooks        2014         20  10.0   7.0   69.0
# 10    1    20  TEN      K.Wright        2012         22  15.0   5.0  104.0
# 5     2    49  PHI     D.Jackson        2008         21  16.0  15.0  120.0
# 4     3    85  HOU      B.Miller        2016         23  10.0   6.0   28.0
# 8     1     4  CIN       A.Green        2011         23  15.0  15.0  115.0
# 2     3    88  ARI     A.Roberts        2010         22  15.0   2.0   49.0
# 3     3    96  DET    K.Golladay        2017         23  11.0   5.0   48.0
# 18    2    39  TAM        A.Benn        2010         21  15.0   9.0   38.0
# 16    1    26  KAN     J.Baldwin        2011         22  11.0   3.0   52.0
# 1     1    22  BAL     M.Clayton        2005         23  14.0  10.0   87.0
# 11    3    78  GNB       J.Jones        2007         23  16.0   9.0   80.0
# 9     1     7  MIN  T.Williamson        2005         22  14.0   3.0   52.0
# 13    1    32  IND    A.Gonzalez        2007         22  13.0   9.0   51.0
# 12    3    68  TEN        C.Roby        2005         22  13.0   6.0   43.0
#
#     WR Tgt Share  ...  Projected Yds Share  Projected Yds  Projected TD Share  \
# 7       0.211429  ...             0.368283     980.000000            0.227273
# 6       0.192171  ...             0.495570    1036.732673            0.533333
# 17      0.237569  ...             0.191993     598.249408            0.240000
# 19      0.257862  ...             0.800485    1982.000000            0.642857
# 0       0.147541  ...             0.166505     515.000000            0.166667
# 14      0.299419  ...             0.576327    1601.036502            0.607143
# 15      0.244681  ...             0.594479    1539.105712            0.402597
# 10      0.317073  ...             0.273961     626.000000            0.333333
# 5       0.331492  ...             0.610772    1599.000000            0.545455
# 4       0.103321  ...            -0.018937     -31.965517            0.055901
# 8       0.357143  ...             0.888654    2099.000000            1.000000
# 2       0.133152  ...             0.177244     434.778860            0.300000
# 3       0.148148  ...             0.496644    1480.000000            0.444444
# 18      0.205405  ...             0.321188     476.000000            0.214286
# 16      0.141304  ...             0.256597     671.000000            0.222222
# 1       0.388393  ...             0.305052     471.000000            0.400000
# 11      0.229885  ...             0.293252     917.000000            0.142857
# 9       0.180556  ...             0.483380    1047.000000            0.307692
# 13      0.199219  ...             0.276657     672.000000            0.214286
# 12      0.153571  ...            -0.044211     -80.287625           -0.088889
#
#     Projected TD  Rec Pts First Season  Rec Pts/G First Season     Actual  \
# 7       5.000000                 103.6                6.475000   6.881250
# 6       8.000000                  84.3                5.620000   4.850000
# 17      6.000000                  96.7                6.043750   6.230000
# 19      9.000000                  90.8                5.675000   9.433333
# 0       3.000000                  48.6                3.037500   3.384615
# 14     12.750000                 135.2                8.450000   9.231250
# 15      4.428571                  73.0                7.300000  10.487500
# 10      4.000000                  86.6                5.773333   7.493750
# 5       6.000000                 103.2                6.450000  11.306667
# 4       0.391304                  15.9                1.590000   2.018182
# 8      14.000000                 147.7                9.846667  12.562500
# 2       3.000000                  42.7                2.846667   4.412500
# 3       8.000000                  65.7                5.972727   9.086667
# 18      3.000000                  51.5                3.433333   4.435714
# 16      2.000000                  31.4                2.854545   2.566667
# 1       2.000000                  59.1                4.221429   7.743750
# 11      3.000000                  79.6                4.975000   3.340000
# 9       4.000000                  49.2                3.514286   3.250000
# 13      3.000000                  75.6                5.815385   5.650000
# 12     -0.800000                  34.9                2.684615   0.233333
#
#     Prediction  Absolute Error     Error
# 7     6.981187        0.099937  0.099937
# 6     4.973860        0.123860  0.123860
# 17    6.537673        0.307673  0.307673
# 19    8.955696        0.477637 -0.477637
# 0     4.473657        1.089042  1.089042
# 14    8.047820        1.183430 -1.183430
# 15    9.297176        1.190324 -1.190324
# 10    6.158193        1.335557 -1.335557
# 5     9.922789        1.383878 -1.383878
# 4     0.352674        1.665507 -1.665507
# 8    10.788270        1.774230 -1.774230
# 2     2.431197        1.981303 -1.981303
# 3     7.056241        2.030425 -2.030425
# 18    6.759983        2.324269  2.324269
# 16    4.922282        2.355615  2.355615
# 1     5.127595        2.616155 -2.616155
# 11    6.123245        2.783245  2.783245
# 9     6.648856        3.398856  3.398856
# 13    9.203989        3.553989  3.553989
# 12    3.852025        3.618691  3.618691
#
# [20 rows x 44 columns]

# %% [markdown]
# **CURRENT BEST FEATURES LIST**:
#
#     ['Tgt', 'Projected Tgt Share', 'Yds', 'TD', 'Yds', Rec', '1D', 'Y/G', 'EYds', 'Rec Pts First Season', 'Rec Pts/G First Season', 'Rnd', 'GS']
#
#     RMSE: 1.9745377338693273
#
# Thoughts:
#
# - One hot encode round
# - use pick straight up
# - use year straight up (?)
# - use age draft straight up
# - use each stat straight up
# - MIGHT NEED MORE DATA
#
# Possible more features:
#
# - Target share
# - Yard share
# - Number of receivers ahead of them for their team
# - Number of available targets: Targets that left team - Targets that came into team ?
# - Receivers drafted in first 2 days by team

# %%
plt.scatter(temp['Actual'] , temp['Prediction'], c='b', label = 'Validation')
plt.scatter(temp_train['Actual'], temp_train['Prediction'], c = 'g', label = 'Training')
plt.plot(range(18), range(18), color = 'r')
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.legend(loc='upper left')
plt.show()
#Save this FIGURE and then

# %%
pl.score(X_valid[small_selection + small_sqrt + ['Rnd', 'Age Draft']], y_valid)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py:97: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# 0.6089469215836824
