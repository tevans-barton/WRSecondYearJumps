# %% [markdown]
# <div style="text-align: right"> Tommy Evans-Barton </div>
# <div style="text-align: right"> WR Year 2 Jumps </div>
#
# # Analysis and Modeling Notebook
#
# The purpose of this notebook is to develop the model used to predict second year production for receivers based on their statistics in their first year. This notebook will also serve as a preliminary 'final notebook' before the final presentation of this project's findings.

# %%
import os
import sys
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import Binarizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import scipy.stats

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
TOP_PATH = os.environ['PWD']

# %% [markdown]
# ## Reading in Data

# %%
df = pd.read_csv(TOP_PATH + '/data/final/FINAL_DATA.csv')
df
# Out:
#      Rnd  Pick Team              Player  First Year  Age Draft     G    GS  \
# 0      1     3  CLE           B.Edwards        2005         22  10.0   7.0
# 1      1     7  MIN        T.Williamson        2005         22  14.0   3.0
# 2      1    10  DET          M.Williams        2005         21  14.0   4.0
# 3      1    21  JAX             M.Jones        2005         22  16.0   1.0
# 4      1    22  BAL           M.Clayton        2005         23  14.0  10.0
# ..   ...   ...  ...                 ...         ...        ...   ...   ...
# 125    2    57  PHI  J.Arcega-Whiteside        2019         22  16.0   5.0
# 126    2    64  SEA           D.Metcalf        2019         21  16.0  15.0
# 127    3    66  PIT           D.Johnson        2019         23  16.0  12.0
# 128    3    76  WAS          T.McLaurin        2019         23  14.0  14.0
# 129    3    93  BAL            M.Boykin        2019         22  16.0  11.0
#
#        Tgt  WR Tgt Share  ...  Projected Rec Share  Projected Rec  \
# 0     59.0      0.226923  ...             0.425007      61.201005
# 1     52.0      0.180556  ...             0.484076      76.000000
# 2     57.0      0.256757  ...             0.381579      43.500000
# 3     69.0      0.206587  ...             0.582418     106.000000
# 4     87.0      0.388393  ...             0.338462      44.000000
# ..     ...           ...  ...                  ...            ...
# 125   22.0      0.126437  ...             0.485149      49.000000
# 126  100.0      0.375940  ...             0.424419      73.000000
# 127   92.0      0.380165  ...             0.406897      59.000000
# 128   93.0      0.505435  ...             0.508772      58.000000
# 129   22.0      0.122905  ...             0.298246      34.000000
#
#      Projected Yds Share  Projected Yds  Projected TD Share  Projected TD  \
# 0               0.498598     981.739542            0.222222           2.0
# 1               0.483380    1047.000000            0.307692           4.0
# 2               0.257708     374.707921           -0.444444          -4.0
# 3               0.563735    1455.000000            0.611111          11.0
# 4               0.305052     471.000000            0.400000           2.0
# ..                   ...            ...                 ...           ...
# 125             0.450466     532.000000            0.400000           4.0
# 126             0.457451    1145.000000            0.444444           8.0
# 127             0.345704     680.000000            0.454545           5.0
# 128             0.620108     919.000000            0.875000           7.0
# 129             0.331918     469.000000            0.294118           5.0
#
#      Rec Pts First Season  Rec Pts/G First Season  Rec Pts Second Season  \
# 0                    69.2                6.920000                  124.4
# 1                    49.2                3.514286                   45.5
# 2                    41.0                2.928571                   15.9
# 3                    73.2                4.575000                   88.3
# 4                    59.1                4.221429                  123.9
# ..                    ...                     ...                    ...
# 125                  22.9                1.431250                    NaN
# 126                 132.0                8.250000                    NaN
# 127                  98.0                6.125000                    NaN
# 128                 133.9                9.564286                    NaN
# 129                  37.8                2.362500                    NaN
#
#      Rec Pts/G Second Season
# 0                   7.775000
# 1                   3.250000
# 2                   1.987500
# 3                   6.307143
# 4                   7.743750
# ..                       ...
# 125                      NaN
# 126                      NaN
# 127                      NaN
# 128                      NaN
# 129                      NaN
#
# [130 rows x 42 columns]

# %% [markdown]
# ## Splitting the Data into Modeling and Prediction Data
# Some of the data (the players who have not yet had second seasons) don't have a target for us to model onto, since this is a 'supervised learning' problem. These players will be moved into a different dataframe for future use.

# %%
df_model = df[df['First Year'] < 2019].reset_index(drop = True)
df_prediction = df[df['First Year'] == 2019].reset_index(drop = True)

# %%
df_model
# Out:
#      Rnd  Pick Team        Player  First Year  Age Draft     G    GS   Tgt  \
# 0      1     3  CLE     B.Edwards        2005         22  10.0   7.0  59.0
# 1      1     7  MIN  T.Williamson        2005         22  14.0   3.0  52.0
# 2      1    10  DET    M.Williams        2005         21  14.0   4.0  57.0
# 3      1    21  JAX       M.Jones        2005         22  16.0   1.0  69.0
# 4      1    22  BAL     M.Clayton        2005         23  14.0  10.0  87.0
# ..   ...   ...  ...           ...         ...        ...   ...   ...   ...
# 115    2    51  CHI      A.Miller        2018         23  15.0   4.0  54.0
# 116    2    60  PIT  J.Washington        2018         22  14.0   6.0  38.0
# 117    2    61  JAX       D.Chark        2018         21  11.0   0.0  32.0
# 118    3    81  DAL      M.Gallup        2018         22  16.0   8.0  68.0
# 119    3    91  NOR       T.Smith        2018         22  15.0   7.0  44.0
#
#      WR Tgt Share  ...  Projected Rec Share  Projected Rec  \
# 0        0.226923  ...             0.425007      61.201005
# 1        0.180556  ...             0.484076      76.000000
# 2        0.256757  ...             0.381579      43.500000
# 3        0.206587  ...             0.582418     106.000000
# 4        0.388393  ...             0.338462      44.000000
# ..            ...  ...                  ...            ...
# 115      0.192171  ...             0.544404      98.537037
# 116      0.094763  ...             0.550607     136.000000
# 117      0.109589  ...             0.208546      34.618557
# 118      0.311927  ...             0.787760     107.923077
# 119      0.159420  ...             0.256039      53.000000
#
#      Projected Yds Share  Projected Yds  Projected TD Share  Projected TD  \
# 0               0.498598     981.739542            0.222222      2.000000
# 1               0.483380    1047.000000            0.307692      4.000000
# 2               0.257708     374.707921           -0.444444     -4.000000
# 3               0.563735    1455.000000            0.611111     11.000000
# 4               0.305052     471.000000            0.400000      2.000000
# ..                   ...            ...                 ...           ...
# 115             0.495570    1036.732673            0.533333      8.000000
# 116             0.532306    1623.000000            0.695652     16.000000
# 117             0.291061     596.675743            0.148148      1.333333
# 118             0.795709    1346.339575            0.677778      6.100000
# 119             0.320792     810.000000            0.409091      9.000000
#
#      Rec Pts First Season  Rec Pts/G First Season  Rec Pts Second Season  \
# 0                    69.2                6.920000                  124.4
# 1                    49.2                3.514286                   45.5
# 2                    41.0                2.928571                   15.9
# 3                    73.2                4.575000                   88.3
# 4                    59.1                4.221429                  123.9
# ..                    ...                     ...                    ...
# 115                  84.3                5.620000                   77.6
# 116                  27.7                1.978571                   91.5
# 117                  17.4                1.581818                  148.8
# 118                  62.7                3.918750                  146.7
# 119                  72.7                4.846667                   53.4
#
#      Rec Pts/G Second Season
# 0                   7.775000
# 1                   3.250000
# 2                   1.987500
# 3                   6.307143
# 4                   7.743750
# ..                       ...
# 115                 4.850000
# 116                 6.100000
# 117                 9.920000
# 118                10.478571
# 119                 4.854545
#
# [120 rows x 42 columns]

# %% [markdown]
# ## Train-Valid-Test Splitting
# Next I'm going to split the modeling data into pieces in order to have part of it to train the model on, and part of it to test on. In terms of the training, I chose to use the k-folds cross validation strategy, due to the low amount of samples, with k = 5.

# %%
X_full_train, X_test, y_full_train, y_test = train_test_split(df_model.drop(
    ['Rec Pts Second Season', 'Rec Pts/G Second Season'], axis = 1), 
    df_model['Rec Pts/G Second Season'], test_size = 0.2, random_state = 3)
X_full_train = X_full_train.reset_index(drop = True)
X_test = X_test.reset_index(drop = True)
y_full_train = y_full_train.reset_index(drop = True)
y_test = y_test.reset_index(drop = True)

# %%
kf = KFold(n_splits = 5, shuffle = True, random_state = 12)

# %% [markdown]
# ## Create a Baseline Model
# Its important to have some kind of baseline (or dummy) model to compare our model to. For the purposes of this project, the baseline will be predicting that the receiver has the same Rec Pts/G in their second season as their first.
#
# Based on this, it seems that the average $R^2$ coefficient for the baseline is around *0.249*, giving us the number to beat.

# %%
baseline_scores = []
for train_index, test_index in kf.split(X_full_train):
    baseline = X_full_train.iloc[test_index]['Rec Pts/G First Season']
    baseline_scores.append(r2_score(y_full_train.iloc[test_index], baseline))
    print(r2_score(y_full_train.iloc[test_index], baseline))
print('---------------------------')
print('MEAN BASELINE SCORE: {s}'.format(s = np.mean(baseline_scores)))
print('MEDIAN BASELINE SCORE: {s}'.format(s = np.median(baseline_scores)))
# Out:
# 0.4033208768271024
# 0.2025675962702247
# -0.023643489000828577
# 0.26032434446511454
# 0.4020393174209883
# ---------------------------
# MEAN BASELINE SCORE: 0.24892172919652028
# MEDIAN BASELINE SCORE: 0.26032434446511454

# %% [markdown]
# ## Building the Model

# %% [markdown]
# ### Defining and Sorting the Different Features

# %%
cat_feat = ['Rnd', 'First Year', 'Age Draft']
thresh_feat = ['G', 'GS']
reg_feat = ['Pick', 'Tgt', 'Catch Rate', 'Y/R', 'TD', 'WR TD Share', 'Lng', 'Y/Tgt', 'Y/G', 
        'Projected Tgt Share', 'Projected Tgt', 'Projected Rec Share', 'Projected Rec', 'Projected Yds Share',
        'Projected Yds', 'Projected TD Share', 'Projected TD', 'DYAR', 'YAR', 'DVOA', 'VOA', 'DPI Pens', 'DPI Yds']
sqrt_feat = ['WR Tgt Share', 'Rec', 'WR Rec Share', 'Yds', 'WR Yds Share', '1D', 
                 'R/G', 'EYds', 'Rec Pts First Season', 'Rec Pts/G First Season']

# %%
cat_selection = ['First Year', 'Rnd']
thresh_selection = ['GS', 'TD']
sqrt_selection = ['Yds', '1D', 'EYds', 'WR Tgt Share', 'WR Rec Share']
log_shift_selection = ['DYAR']
reg_selection = ['Y/G']

# %% [markdown]
# ### Defining the Different Transformers

# %%
cat_transformer_years = Pipeline(steps=[
    ('onehot', OneHotEncoder(categories = [range(2005, 2019)], handle_unknown = 'ignore'))])

cat_transformer_rnd = Pipeline(steps=[
    ('onehot', OneHotEncoder(categories = 'auto', handle_unknown = 'ignore'))])

thresh_transformer_1 = Pipeline(steps=[
    ('binarizer', Binarizer(threshold = 8))
])

thresh_transformer_2 = Pipeline(steps = [
    ('binarizer', Binarizer(threshold = 0))
])

thresh_td = Pipeline(steps = [
    ('binarizer', Binarizer(threshold = 1))
])

yard_share_transformer = Pipeline(steps = [
    ('sqrt', FunctionTransformer(lambda x : x **.5)),
    ('binarizer', Binarizer(threshold = .475))
])

sqrt_transformer = Pipeline(steps = [
    ('sqrt', FunctionTransformer(lambda x : x**.5))
])

log_shift_transformer = Pipeline(steps = [
    ('log_shift', FunctionTransformer(lambda x : np.log(x + 200)))
])

num_transformer = Pipeline(steps=[
    ('none', FunctionTransformer(lambda x : x))
])

preproc = ColumnTransformer(transformers=[('none', num_transformer, reg_selection), 
                                        ('sqrt', sqrt_transformer, sqrt_selection), 
                                        ('log', log_shift_transformer, log_shift_selection),
                                        ('cat1', cat_transformer_years, ['First Year']),
                                        ('cat2', cat_transformer_rnd, ['Rnd']),
                                        ('thresh1', thresh_transformer_1, ['GS']),
                                        ('thresh2', thresh_transformer_2, ['GS']),
                                        ('threshTD', thresh_td, ['TD']),
                                        ('ydshare', yard_share_transformer, ['WR Yds Share'])])

# %% [markdown]
# ### Defining the Different Pipelines

# %%
alpha_val = .35

# %%
pl_1 = Pipeline(steps=[('preprocessor', preproc), ('regressor', Ridge(alpha = alpha_val, normalize = True))])
pl_2 = Pipeline(steps=[('preprocessor', preproc), ('regressor', Ridge(alpha = alpha_val, normalize = True))])
pl_3 = Pipeline(steps=[('preprocessor', preproc), ('regressor', Ridge(alpha = alpha_val, normalize = True))])
pl_4 = Pipeline(steps=[('preprocessor', preproc), ('regressor', Ridge(alpha = alpha_val, normalize = True))])
pl_5 = Pipeline(steps=[('preprocessor', preproc), ('regressor', Ridge(alpha = alpha_val, normalize = True))])

# %% [markdown]
# ### Fit the Different Pipelines

# %%
count = 1
pipeline_scores = []
pipeline_rmse = []
features = reg_selection + sqrt_selection + log_shift_selection + cat_selection + thresh_selection + ['WR Yds Share']
for train_index, test_index in kf.split(X_full_train):
    eval('pl_{num}'.format(num = str(count))).fit(X_full_train[features].iloc[train_index], 
                                                  y_full_train.iloc[train_index])
    score = eval('pl_{num}'.format(num = str(count))).score(X_full_train[features].iloc[test_index], 
                                                            y_full_train.iloc[test_index])
    mse = mean_squared_error(y_full_train.iloc[test_index], 
                              eval('pl_{num}'.format(num = str(count)))
                              .predict(X_full_train[features].iloc[test_index]))
    rmse = mse ** .5
    pipeline_rmse.append(rmse)
    pipeline_scores.append(score)
    print('R2 SCORE PIPELINE {c}: {s}'.format(c = count, s = score))
    #print('RMSE: {r}'.format(r = rmse))
    count += 1
print('---------------------------')
print('MEDIAN SCORE: {s}'.format(s = np.median(pipeline_scores)))
print('MEAN SCORE: {s}'.format(s = np.mean(pipeline_scores)))
# print('MEDIAN RMSE: {s}'.format(s = np.median(pipeline_rmse)))
# print('MEAN RMSE: {s}'.format(s = np.mean(pipeline_rmse)))
# Out:
# R2 SCORE PIPELINE 1: 0.6712461119627633
# R2 SCORE PIPELINE 2: 0.4200534115804785
# R2 SCORE PIPELINE 3: 0.53552055008639
# R2 SCORE PIPELINE 4: 0.46961600569824646
# R2 SCORE PIPELINE 5: 0.5248078875700556
# ---------------------------
# MEDIAN SCORE: 0.5248078875700556
# MEAN SCORE: 0.5242487933795867

# %% [markdown]
# ### Calculate the Mean Pipeline

# %%
coefs_mean = (pl_1.named_steps['regressor'].coef_ + pl_2.named_steps['regressor'].coef_ 
                + pl_3.named_steps['regressor'].coef_ + pl_4.named_steps['regressor'].coef_ +
             pl_5.named_steps['regressor'].coef_) / 5
intercept_mean = (pl_1.named_steps['regressor'].intercept_ + pl_2.named_steps['regressor'].intercept_ 
                        + pl_3.named_steps['regressor'].intercept_ + pl_4.named_steps['regressor'].intercept_) / 5

# %%
coefs_mean
# Out:
# array([ 0.03216923,  0.06311527,  0.25248721,  0.04701663, -0.41064024,
#        -1.79426669,  0.84898942, -0.70625505,  1.29031171, -1.13742002,
#        -0.02078758,  0.75592938,  0.0815552 ,  0.36855383,  0.70901908,
#        -1.54020912,  0.53412134, -1.00164348, -0.96288193,  1.97329382,
#         0.17000279,  0.68140717, -0.43045693, -0.28358388,  0.1595888 ,
#        -1.2496086 ,  0.67660286,  0.82540477])

# %%
intercept_mean
# Out:
# -0.9423912490120756

# %%
df_coeff = pd.DataFrame(zip(reg_selection + ['SQRT ' + x for x in sqrt_selection] + 
                            ['Log Shift ' + x for x in log_shift_selection] + 
                            list(range(2005, 2019)) + ['Round 1', 'Round 2', 'Round 3'] + 
                            ['GS > 8', 'GS > 0', 'TD > 1'] + ['SQRT WR Yds Share > .475'], coefs_mean))
df_coeff.columns = ['Feature', 'Coefficient']
df_coeff
# Out:
#                      Feature  Coefficient
# 0                        Y/G     0.032169
# 1                   SQRT Yds     0.063115
# 2                    SQRT 1D     0.252487
# 3                  SQRT EYds     0.047017
# 4          SQRT WR Tgt Share    -0.410640
# 5          SQRT WR Rec Share    -1.794267
# 6             Log Shift DYAR     0.848989
# 7                       2005    -0.706255
# 8                       2006     1.290312
# 9                       2007    -1.137420
# 10                      2008    -0.020788
# 11                      2009     0.755929
# 12                      2010     0.081555
# 13                      2011     0.368554
# 14                      2012     0.709019
# 15                      2013    -1.540209
# 16                      2014     0.534121
# 17                      2015    -1.001643
# 18                      2016    -0.962882
# 19                      2017     1.973294
# 20                      2018     0.170003
# 21                   Round 1     0.681407
# 22                   Round 2    -0.430457
# 23                   Round 3    -0.283584
# 24                    GS > 8     0.159589
# 25                    GS > 0    -1.249609
# 26                    TD > 1     0.676603
# 27  SQRT WR Yds Share > .475     0.825405

# %% [markdown]
# ### Create the Final Pipeline

# %%
pl_final = Pipeline(steps=[('preprocessor', preproc), ('regressor', Ridge(alpha = alpha_val, normalize = True))])
pl_final.named_steps['regressor'].coef_ = coefs_mean
pl_final.named_steps['regressor'].intercept_ = intercept_mean

# %%
pl_final.score(X_full_train[features], y_full_train)
# Out:
# 0.62024851722975

# %%
y_train_pred = pl_final.predict(X_full_train[reg_selection + sqrt_selection + log_shift_selection + cat_selection + thresh_selection + ['WR Yds Share']])

# %%
plt.scatter(y_full_train, y_train_pred - y_full_train, c = 'b', label = 'Training')
plt.plot(range(18), [0] * 18, color = 'r', label = 'Correct Prediction')
plt.xlabel('Actual')
plt.ylabel('Residual')
plt.legend(loc='upper right')
plt.show()
#Save this FIGURE and then

# %%
plt.scatter(y_train_pred, y_train_pred - y_full_train, c = 'g', label = 'Training')
plt.plot(range(14), [0] * 14, color = 'r', label = 'Correct Prediction')
plt.xlabel('Prediction')
plt.ylabel('Residual')
plt.legend(loc='upper left')
plt.show()
#Save this FIGURE and then

# %%
df_full_train = X_full_train.copy()

# %%
df_full_train['True'] = y_full_train

# %%
df_full_train['Predicted'] = y_train_pred

# %%
df_full_train['Error'] = y_train_pred - y_full_train

# %%
df_full_train['Absolute Error'] = np.abs(y_train_pred - y_full_train)

# %%
df_full_train.sort_values('Absolute Error')
# Out:
#     Rnd  Pick Team      Player  First Year  Age Draft     G    GS    Tgt  \
# 18    3    76  KAN    C.Conley        2015         22  16.0   5.0   31.0
# 4     3    96  DET  K.Golladay        2017         23  11.0   5.0   48.0
# 43    2    34  TEN    J.Hunter        2013         22  14.0   0.0   42.0
# 31    1     9  MIA      T.Ginn        2007         22  16.0   9.0   71.0
# 11    2    41  BUF     R.Woods        2013         21  14.0  14.0   85.0
# ..  ...   ...  ...         ...         ...        ...   ...   ...    ...
# 70    1    10  DET  M.Williams        2005         21  14.0   4.0   57.0
# 22    2    52  GNB  G.Jennings        2006         22  14.0  11.0  104.0
# 69    2    45  CHI   A.Jeffery        2012         22  10.0   6.0   48.0
# 91    2    59  NWE    A.Dobson        2013         22  12.0   9.0   72.0
# 83    2    44  SFO    D.Pettis        2018         22  12.0   7.0   45.0
#
#     WR Tgt Share  ...  Projected Yds Share  Projected Yds  Projected TD Share  \
# 18      0.131356  ...             0.171244     318.000000            0.090909
# 4       0.148148  ...             0.496644    1480.000000            0.444444
# 43      0.122093  ...            -0.248505    -652.573410            0.088889
# 31      0.381720  ...             0.608307     691.037288            0.457143
# 11      0.290102  ...             0.693584    1325.438298            0.573427
# ..           ...  ...                  ...            ...                 ...
# 70      0.256757  ...             0.257708     374.707921           -0.444444
# 22      0.297994  ...             0.275676     663.000000            0.307692
# 69      0.145897  ...             0.244382     609.000000            0.235294
# 91      0.186528  ...             0.066713     182.594554            0.166667
# 83      0.225000  ...             0.460550     753.000000            0.428571
#
#     Projected TD  Rec Pts First Season  Rec Pts/G First Season       True  \
# 18      1.000000                  25.9                1.618750   3.312500
# 4       8.000000                  65.7                5.972727   9.086667
# 43      0.800000                  59.4                4.242857   5.650000
# 31      2.285714                  54.0                3.375000   5.687500
# 11      6.307692                  76.7                5.478571   6.243750
# ..           ...                   ...                     ...        ...
# 70     -4.000000                  41.0                2.928571   1.987500
# 22      4.000000                  81.2                5.800000  12.615385
# 69      4.000000                  54.7                5.470000  11.506250
# 91      2.666667                  75.9                6.325000   0.950000
# 83      6.000000                  76.7                6.391667   2.081818
#
#     Predicted     Error  Absolute Error
# 18   3.350727  0.038227        0.038227
# 4    9.181041  0.094374        0.094374
# 43   5.541631 -0.108369        0.108369
# 31   5.827943  0.140443        0.140443
# 11   6.100681 -0.143069        0.143069
# ..        ...       ...             ...
# 70   5.900214  3.912714        3.912714
# 22   8.609790 -4.005595        4.005595
# 69   7.114937 -4.391313        4.391313
# 91   5.685129  4.735129        4.735129
# 83   7.582042  5.500224        5.500224
#
# [96 rows x 44 columns]

# %%
np.mean(df_full_train['Error'] ** 2) ** .5
# Out:
# 2.1407451960290587

# %%
df_full_train[['Player', 'Team'] + features + ['True', 'Predicted', 'Error', 'Absolute Error']].sort_values('Absolute Error', ascending = False)
# Out:
#         Player Team   Y/G    Yds    1D   EYds  WR Tgt Share  WR Rec Share  \
# 83    D.Pettis  SFO  38.9  467.0  19.0  461.0      0.225000      0.232759
# 91    A.Dobson  NWE  43.3  519.0  25.0  583.0      0.186528      0.158120
# 69   A.Jeffery  CHI  36.7  367.0  17.0  408.0      0.145897      0.123711
# 22  G.Jennings  GNB  45.1  632.0  29.0  543.0      0.297994      0.264706
# 70  M.Williams  DET  25.0  350.0  20.0  337.0      0.256757      0.254386
# ..         ...  ...   ...    ...   ...    ...           ...           ...
# 11     R.Woods  BUF  41.9  587.0  26.0  539.0      0.290102      0.281690
# 31      T.Ginn  MIA  26.3  420.0  18.0  326.0      0.381720      0.369565
# 43    J.Hunter  TEN  25.3  354.0  16.0  317.0      0.122093      0.091837
# 4   K.Golladay  DET  43.4  477.0  18.0  498.0      0.148148      0.132701
# 18    C.Conley  KAN  12.4  199.0  12.0  261.0      0.131356      0.110390
#
#      DYAR  First Year  Rnd    GS   TD  WR Yds Share       True  Predicted  \
# 83  109.0        2018    2   7.0  5.0      0.285627   2.081818   7.582042
# 91   46.0        2013    2   9.0  4.0      0.189624   0.950000   5.685129
# 69   72.0        2012    2   6.0  3.0      0.147271  11.506250   7.114937
# 22  -97.0        2006    2  11.0  3.0      0.262786  12.615385   8.609790
# 70  -16.0        2005    1   4.0  1.0      0.240715   1.987500   5.900214
# ..    ...         ...  ...   ...  ...           ...        ...        ...
# 11    5.0        2013    2  14.0  3.0      0.307169   6.243750   6.100681
# 31  -75.0        2007    1   9.0  2.0      0.369718   5.687500   5.827943
# 43   30.0        2013    2   0.0  4.0      0.134806   5.650000   5.541631
# 4   130.0        2017    3   5.0  3.0      0.160067   9.086667   9.181041
# 18   39.0        2015    3   5.0  1.0      0.107162   3.312500   3.350727
#
#        Error  Absolute Error
# 83  5.500224        5.500224
# 91  4.735129        4.735129
# 69 -4.391313        4.391313
# 22 -4.005595        4.005595
# 70  3.912714        3.912714
# ..       ...             ...
# 11 -0.143069        0.143069
# 31  0.140443        0.140443
# 43 -0.108369        0.108369
# 4   0.094374        0.094374
# 18  0.038227        0.038227
#
# [96 rows x 18 columns]

# %%
df_full_train[df_full_train['True'] < 10][0:].sort_values('Absolute Error', ascending = False)[0:30].corr()
# Out:
#                              Rnd      Pick  First Year  Age Draft         G  \
# Rnd                     1.000000  0.936021   -0.036108   0.245072 -0.125392
# Pick                    0.936021  1.000000   -0.019470   0.159702 -0.157046
# First Year             -0.036108 -0.019470    1.000000   0.026547  0.049804
# Age Draft               0.245072  0.159702    0.026547   1.000000  0.013829
# G                      -0.125392 -0.157046    0.049804   0.013829  1.000000
# GS                     -0.240532 -0.239617    0.124073  -0.262738  0.225776
# Tgt                    -0.423906 -0.399703    0.145232  -0.142060  0.509419
# WR Tgt Share           -0.472915 -0.487268    0.126705  -0.298556  0.419865
# Rec                    -0.382581 -0.339314    0.190516  -0.176052  0.580850
# WR Rec Share           -0.464654 -0.476726    0.145345  -0.320468  0.427375
# Catch Rate              0.031283  0.139664    0.118106  -0.162959  0.298282
# Yds                    -0.371604 -0.341542    0.157330  -0.224697  0.529472
# WR Yds Share           -0.444915 -0.472644    0.117802  -0.337989  0.316099
# Y/R                     0.004358 -0.015523   -0.097955  -0.198970 -0.030000
# TD                     -0.217016 -0.249609    0.278177  -0.067810  0.164633
# WR TD Share            -0.375539 -0.415060    0.243979  -0.184992  0.024297
# 1D                     -0.406970 -0.366150    0.153827  -0.313216  0.481754
# Lng                    -0.232585 -0.164979    0.076633   0.133594  0.307138
# Y/Tgt                   0.011780  0.083851    0.019397  -0.252039  0.184351
# R/G                    -0.451003 -0.405427    0.194008  -0.200863  0.332789
# Y/G                    -0.432080 -0.398125    0.156469  -0.250236  0.294342
# DYAR                   -0.072094 -0.038726    0.159494  -0.248612  0.219987
# YAR                    -0.081041 -0.054263    0.164086  -0.272719  0.197375
# DVOA                    0.026105  0.102185    0.084700  -0.214943  0.140543
# VOA                     0.033814  0.108984    0.098626  -0.234083  0.118662
# EYds                   -0.361485 -0.311328    0.217880  -0.252318  0.509663
# DPI Pens               -0.225642 -0.127511    0.202523  -0.042659 -0.029102
# DPI Yds                -0.302102 -0.221249    0.124476  -0.064765  0.049812
# Projected Tgt Share    -0.348561 -0.440283    0.309293   0.310116  0.233109
# Projected Tgt          -0.278439 -0.357812    0.273855   0.404922  0.279674
# Projected Rec Share    -0.368304 -0.476659    0.281164   0.315891  0.193033
# Projected Rec          -0.285145 -0.377693    0.261597   0.447061  0.283785
# Projected Yds Share    -0.334404 -0.431260    0.348579   0.270412  0.191985
# Projected Yds          -0.257591 -0.335710    0.332091   0.381769  0.344650
# Projected TD Share     -0.187342 -0.263632    0.451562   0.253157 -0.090408
# Projected TD           -0.068616 -0.163587    0.420781   0.344196  0.018123
# Rec Pts First Season   -0.339962 -0.334782    0.226856  -0.177339  0.420036
# Rec Pts/G First Season -0.363906 -0.354853    0.242138  -0.168296  0.181766
# True                   -0.252730 -0.163195   -0.005874  -0.332918  0.283274
# Predicted              -0.542545 -0.493538    0.123022  -0.384455  0.240025
# Error                  -0.254341 -0.319655    0.141293   0.023369 -0.114417
# Absolute Error          0.055520  0.046765    0.189257  -0.033978 -0.327561
#
#                               GS       Tgt  WR Tgt Share       Rec  \
# Rnd                    -0.240532 -0.423906     -0.472915 -0.382581
# Pick                   -0.239617 -0.399703     -0.487268 -0.339314
# First Year              0.124073  0.145232      0.126705  0.190516
# Age Draft              -0.262738 -0.142060     -0.298556 -0.176052
# G                       0.225776  0.509419      0.419865  0.580850
# GS                      1.000000  0.719635      0.734157  0.678114
# Tgt                     0.719635  1.000000      0.905602  0.951253
# WR Tgt Share            0.734157  0.905602      1.000000  0.888690
# Rec                     0.678114  0.951253      0.888690  1.000000
# WR Rec Share            0.708206  0.861554      0.979556  0.885008
# Catch Rate              0.065179  0.068635      0.147202  0.348783
# Yds                     0.738217  0.892639      0.857827  0.950210
# WR Yds Share            0.742616  0.803095      0.947742  0.810087
# Y/R                     0.132287 -0.141169     -0.021973 -0.102501
# TD                      0.502356  0.472379      0.451693  0.530410
# WR TD Share             0.520802  0.517253      0.573702  0.502746
# 1D                      0.692605  0.865162      0.850506  0.932191
# Lng                     0.350817  0.446039      0.442795  0.422868
# Y/Tgt                   0.141840 -0.047940      0.085197  0.167736
# R/G                     0.710490  0.920089      0.897143  0.949511
# Y/G                     0.764403  0.846178      0.850363  0.884199
# DYAR                    0.205754  0.072841      0.171492  0.312185
# YAR                     0.239518  0.085572      0.186976  0.324906
# DVOA                    0.077052 -0.090453      0.044185  0.158282
# VOA                     0.098948 -0.089134      0.047902  0.162306
# EYds                    0.678439  0.796415      0.784810  0.901748
# DPI Pens                0.435523  0.355212      0.354641  0.285862
# DPI Yds                 0.322657  0.353827      0.350821  0.315985
# Projected Tgt Share     0.101134  0.268422      0.262187  0.166026
# Projected Tgt           0.038651  0.267092      0.141960  0.148478
# Projected Rec Share     0.040346  0.218575      0.246115  0.129830
# Projected Rec          -0.033825  0.216158      0.126218  0.130911
# Projected Yds Share     0.123273  0.226165      0.247342  0.146198
# Projected Yds           0.077136  0.230680      0.134423  0.166918
# Projected TD Share      0.118784  0.146053      0.119484  0.111937
# Projected TD            0.040199  0.068521      0.009649  0.083373
# Rec Pts First Season    0.707068  0.794857      0.762851  0.858392
# Rec Pts/G First Season  0.707026  0.723543      0.726351  0.771120
# True                    0.314071  0.315215      0.300516  0.431593
# Predicted               0.650101  0.621081      0.692533  0.709666
# Error                   0.289887  0.256878      0.353882  0.198990
# Absolute Error         -0.021968 -0.153443     -0.042134 -0.151039
#
#                         WR Rec Share  ...  Projected Yds Share  Projected Yds  \
# Rnd                        -0.464654  ...            -0.334404      -0.257591
# Pick                       -0.476726  ...            -0.431260      -0.335710
# First Year                  0.145345  ...             0.348579       0.332091
# Age Draft                  -0.320468  ...             0.270412       0.381769
# G                           0.427375  ...             0.191985       0.344650
# GS                          0.708206  ...             0.123273       0.077136
# Tgt                         0.861554  ...             0.226165       0.230680
# WR Tgt Share                0.979556  ...             0.247342       0.134423
# Rec                         0.885008  ...             0.146198       0.166918
# WR Rec Share                1.000000  ...             0.241726       0.116083
# Catch Rate                  0.278056  ...            -0.237498      -0.213611
# Yds                         0.868257  ...             0.154995       0.167769
# WR Yds Share                0.969249  ...             0.266200       0.111031
# Y/R                         0.030106  ...             0.170447       0.103023
# TD                          0.482785  ...             0.109297       0.134932
# WR TD Share                 0.592241  ...             0.191320       0.122062
# 1D                          0.853409  ...             0.023816       0.030587
# Lng                         0.448558  ...             0.317800       0.253982
# Y/Tgt                       0.207145  ...            -0.063363      -0.091314
# R/G                         0.887906  ...             0.139848       0.097188
# Y/G                         0.855950  ...             0.161910       0.115572
# DYAR                        0.279880  ...            -0.179804      -0.141530
# YAR                         0.296046  ...            -0.183322      -0.153152
# DVOA                        0.172124  ...            -0.201259      -0.205325
# VOA                         0.178148  ...            -0.221882      -0.233249
# EYds                        0.815216  ...             0.058073       0.080215
# DPI Pens                    0.334536  ...             0.219134       0.116317
# DPI Yds                     0.356018  ...             0.324043       0.238783
# Projected Tgt Share         0.230073  ...             0.977188       0.932110
# Projected Tgt               0.096720  ...             0.901244       0.953073
# Projected Rec Share         0.232696  ...             0.970610       0.900221
# Projected Rec               0.095165  ...             0.899260       0.950562
# Projected Yds Share         0.241726  ...             1.000000       0.931722
# Projected Yds               0.116083  ...             0.931722       1.000000
# Projected TD Share          0.119839  ...             0.570986       0.537405
# Projected TD                0.029581  ...             0.453220       0.490712
# Rec Pts First Season        0.783521  ...             0.150157       0.169933
# Rec Pts/G First Season      0.744318  ...             0.140648       0.106801
# True                        0.345366  ...            -0.065643       0.002741
# Predicted                   0.728955  ...             0.102781       0.056616
# Error                       0.334050  ...             0.198433       0.057820
# Absolute Error             -0.026897  ...            -0.015234      -0.160019
#
#                         Projected TD Share  Projected TD  \
# Rnd                              -0.187342     -0.068616
# Pick                             -0.263632     -0.163587
# First Year                        0.451562      0.420781
# Age Draft                         0.253157      0.344196
# G                                -0.090408      0.018123
# GS                                0.118784      0.040199
# Tgt                               0.146053      0.068521
# WR Tgt Share                      0.119484      0.009649
# Rec                               0.111937      0.083373
# WR Rec Share                      0.119839      0.029581
# Catch Rate                       -0.169546     -0.080633
# Yds                               0.151784      0.143650
# WR Yds Share                      0.151018      0.048945
# Y/R                               0.086206      0.067052
# TD                                0.483724      0.568705
# WR TD Share                       0.550206      0.482938
# 1D                                0.082481      0.073144
# Lng                               0.188063      0.107064
# Y/Tgt                            -0.066163     -0.020843
# R/G                               0.165935      0.079208
# Y/G                               0.205658      0.141117
# DYAR                              0.067310      0.216127
# YAR                               0.074892      0.215896
# DVOA                             -0.062133      0.023675
# VOA                              -0.066360      0.016931
# EYds                              0.151050      0.175786
# DPI Pens                          0.175653      0.031343
# DPI Yds                           0.239875      0.104809
# Projected Tgt Share               0.488638      0.360780
# Projected Tgt                     0.459360      0.365344
# Projected Rec Share               0.513712      0.404166
# Projected Rec                     0.488827      0.428420
# Projected Yds Share               0.570986      0.453220
# Projected Yds                     0.537405      0.490712
# Projected TD Share                1.000000      0.908020
# Projected TD                      0.908020      1.000000
# Rec Pts First Season              0.314715      0.347213
# Rec Pts/G First Season            0.370610      0.356635
# True                              0.149106      0.257484
# Predicted                         0.157458      0.121956
# Error                            -0.026454     -0.208427
# Absolute Error                   -0.079002     -0.051355
#
#                         Rec Pts First Season  Rec Pts/G First Season  \
# Rnd                                -0.339962               -0.363906
# Pick                               -0.334782               -0.354853
# First Year                          0.226856                0.242138
# Age Draft                          -0.177339               -0.168296
# G                                   0.420036                0.181766
# GS                                  0.707068                0.707026
# Tgt                                 0.794857                0.723543
# WR Tgt Share                        0.762851                0.726351
# Rec                                 0.858392                0.771120
# WR Rec Share                        0.783521                0.744318
# Catch Rate                          0.358324                0.317115
# Yds                                 0.939661                0.870083
# WR Yds Share                        0.785067                0.783271
# Y/R                                 0.215173                0.241555
# TD                                  0.864077                0.876837
# WR TD Share                         0.781793                0.844444
# 1D                                  0.898400                0.837402
# Lng                                 0.424852                0.417788
# Y/Tgt                               0.368775                0.357334
# R/G                                 0.836427                0.834539
# Y/G                                 0.912147                0.922191
# DYAR                                0.585161                0.555761
# YAR                                 0.599586                0.579995
# DVOA                                0.383684                0.382975
# VOA                                 0.384740                0.391084
# EYds                                0.946516                0.878521
# DPI Pens                            0.290670                0.369682
# DPI Yds                             0.286512                0.340245
# Projected Tgt Share                 0.113874                0.091967
# Projected Tgt                       0.068683                0.019073
# Projected Rec Share                 0.088666                0.071136
# Projected Rec                       0.057868                0.003166
# Projected Yds Share                 0.150157                0.140648
# Projected Yds                       0.169933                0.106801
# Projected TD Share                  0.314715                0.370610
# Projected TD                        0.347213                0.356635
# Rec Pts First Season                1.000000                0.960112
# Rec Pts/G First Season              0.960112                1.000000
# True                                0.533172                0.489646
# Predicted                           0.816853                0.823358
# Error                               0.180881                0.245548
# Absolute Error                      0.003886                0.102723
#
#                             True  Predicted     Error  Absolute Error
# Rnd                    -0.252730  -0.542545 -0.254341        0.055520
# Pick                   -0.163195  -0.493538 -0.319655        0.046765
# First Year             -0.005874   0.123022  0.141293        0.189257
# Age Draft              -0.332918  -0.384455  0.023369       -0.033978
# G                       0.283274   0.240025 -0.114417       -0.327561
# GS                      0.314071   0.650101  0.289887       -0.021968
# Tgt                     0.315215   0.621081  0.256878       -0.153443
# WR Tgt Share            0.300516   0.692533  0.353882       -0.042134
# Rec                     0.431593   0.709666  0.198990       -0.151039
# WR Rec Share            0.345366   0.728955  0.334050       -0.026897
# Catch Rate              0.493016   0.446302 -0.168140       -0.057056
# Yds                     0.505400   0.807790  0.207801       -0.049722
# WR Yds Share            0.339916   0.752771  0.367112        0.084421
# Y/R                     0.108700   0.297329  0.178831        0.399331
# TD                      0.454229   0.646639  0.100627        0.081888
# WR TD Share             0.308549   0.607562  0.251028        0.110228
# 1D                      0.515164   0.823138  0.211535       -0.077015
# Lng                    -0.024995   0.219524  0.271337        0.238904
# Y/Tgt                   0.430705   0.493267 -0.034698        0.200219
# R/G                     0.406743   0.748405  0.273925       -0.057142
# Y/G                     0.471150   0.836586  0.284385        0.065521
# DYAR                    0.498928   0.594879 -0.014711        0.115169
# YAR                     0.518283   0.624123 -0.008589        0.112318
# DVOA                    0.458290   0.492918 -0.071586        0.080375
# VOA                     0.473911   0.503970 -0.080267        0.082435
# EYds                    0.520675   0.821496  0.202459       -0.026596
# DPI Pens               -0.146167   0.108653  0.311382        0.366809
# DPI Yds                -0.075668   0.096848  0.205260        0.165994
# Projected Tgt Share    -0.136574   0.051553  0.236712       -0.044481
# Projected Tgt          -0.135998  -0.041968  0.134450       -0.176654
# Projected Rec Share    -0.112761   0.048459  0.201836       -0.050685
# Projected Rec          -0.078884  -0.032792  0.068815       -0.207699
# Projected Yds Share    -0.065643   0.102781  0.198433       -0.015234
# Projected Yds           0.002741   0.056616  0.057820       -0.160019
# Projected TD Share      0.149106   0.157458 -0.026454       -0.079002
# Projected TD            0.257484   0.121956 -0.208427       -0.051355
# Rec Pts First Season    0.533172   0.816853  0.180881        0.003886
# Rec Pts/G First Season  0.489646   0.823358  0.245548        0.102723
# True                    1.000000   0.671675 -0.594549       -0.427444
# Predicted               0.671675   1.000000  0.196340       -0.112095
# Error                  -0.594549   0.196340  1.000000        0.444078
# Absolute Error         -0.427444  -0.112095  0.444078        1.000000
#
# [42 rows x 42 columns]
