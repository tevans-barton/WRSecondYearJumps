# %% [markdown]
# <div style="text-align: right"> Tommy Evans-Barton </div>
# <div style="text-align: right"> WR Year 2 Jumps </div>
#
# # EDA Post-Cleaning Notebook
#
# This notebook will be analyzing the data after it's transformation and cleaning in order to better inform the model that will be built in the analysis.

# %%
import os
import sys
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats

# %%
# %load_ext autoreload
# %autoreload 2

# %%
TOP_PATH = os.environ['PWD']

# %%
sys.path.append(TOP_PATH + '/src')
sys.path.append(TOP_PATH + '/src/viz')

# %%
df = pd.read_csv(TOP_PATH + '/data/final/FINAL_DATA.csv')

# %%
df_prediction = df[df['First Year'] < 2019]

# %%
df_prediction.columns
# Out:
# Index(['Rnd', 'Pick', 'Team', 'Player', 'First Year', 'Age Draft', 'G', 'GS',
#        'Tgt', 'Rec', 'Ctch%', 'Yds', 'Y/R', 'TD', '1D', 'Lng', 'Y/Tgt', 'R/G',
#        'Y/G', 'DYAR', 'YAR', 'DVOA', 'VOA', 'EYds', 'DPI Pens', 'DPI Yds',
#        'Rec Pts First Season', 'Rec Pts/G First Season',
#        'Rec Pts Second Season', 'Rec Pts/G Second Season'],
#       dtype='object')

# %%
sns.regplot('Pick', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Pick'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is -0.037368527551054576
# Correlation is -0.2829706615245142

# %%
sns.regplot('Age Draft', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Age Draft'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is -0.87073299268731
# Correlation is -0.21626130280323813

# %%
sns.regplot('G', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['G'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.4041950427061973
# Correlation is 0.32223564166122715

# %%
sns.regplot('GS', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['GS'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.35863931694549694
# Correlation is 0.4689803297726532

# %%
sns.regplot('Tgt', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Tgt'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.0715419759249702
# Correlation is 0.6444498296250168

# %%
sns.regplot('Rec', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Rec'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.1100769489730592
# Correlation is 0.626673055083478

# %%
sns.regplot('Ctch%', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Ctch%'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.08037919090502806
# Correlation is 0.22637137856217873

# %%
sns.regplot('Yds', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Yds'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.008731242647497568
# Correlation is 0.7100916342927965

# %%
sns.regplot('Y/R', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Y/R'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.5658736416054408
# Correlation is 0.43261409360807485

# %%
sns.regplot('TD', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['TD'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.7517014011791915
# Correlation is 0.5427920228638605

# %%
sns.regplot('1D', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['1D'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.17626301316277163
# Correlation is 0.6695829145282773

# %%
sns.regplot('Lng', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Lng'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.08006335706723773
# Correlation is 0.4477913119278511

# %%
sns.regplot('Y/Tgt', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Y/Tgt'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.8923956817331786
# Correlation is 0.4884284005517647

# %%
df_prediction.columns
# Out:
# Index(['Rnd', 'Pick', 'Team', 'Player', 'First Year', 'Age Draft', 'G', 'GS',
#        'Tgt', 'Rec', 'Ctch%', 'Yds', 'Y/R', 'TD', '1D', 'Lng', 'Y/Tgt', 'R/G',
#        'Y/G', 'DYAR', 'YAR', 'DVOA', 'VOA', 'EYds', 'DPI Pens', 'DPI Yds',
#        'Rec Pts First Season', 'Rec Pts/G First Season',
#        'Rec Pts Second Season', 'Rec Pts/G Second Season'],
#       dtype='object')

# %%
sns.regplot('R/G', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['R/G'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 1.7002386721552492
# Correlation is 0.6254941489754986

# %%
sns.regplot('Y/G', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Y/G'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.13528806952708802
# Correlation is 0.7170054617406885

# %%
sns.regplot('DYAR', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['DYAR'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.017111394631124207
# Correlation is 0.5042044593450472

# %%
sns.regplot('YAR', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['YAR'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.017105037617651492
# Correlation is 0.5037646427978051

# %%
sns.regplot('DVOA', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['DVOA'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.07259148003372139
# Correlation is 0.4400633880816115

# %%
sns.regplot('VOA', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['VOA'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.07172444968548868
# Correlation is 0.43300680161247357

# %%
sns.regplot('EYds', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['EYds'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.007765758624153738
# Correlation is 0.6772516603458886

# %%
sns.regplot('DPI Pens', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['DPI Pens'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.8111259026324252
# Correlation is 0.2769584248083655

# %%
sns.regplot('DPI Yds', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['DPI Yds'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.02888675778573752
# Correlation is 0.23910063149979296

# %%
sns.regplot('Rec Pts/G First Season', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Rec Pts/G First Season'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.8675169097898531
# Correlation is 0.6830655703257935

# %%
sns.regplot('Rec Pts First Season', 'Rec Pts/G Second Season', df_prediction)
result = scipy.stats.linregress(df_prediction['Rec Pts First Season'], df_prediction['Rec Pts/G Second Season'])
print('Slope is ' + str(result.slope))
print('Correlation is ' + str(result.rvalue))
# Out:
# Slope is 0.05751120450066203
# Correlation is 0.6836475973501068
