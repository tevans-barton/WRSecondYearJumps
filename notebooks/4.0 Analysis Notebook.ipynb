# %%
import os
import sys
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
TOP_PATH = os.environ['PWD']

# %%
pd.read_csv(TOP_PATH + '/data/final/FINAL_DATA.csv')
# Out:
#      Rnd  Pick Team       Player  First Year  Age Draft     G    GS    Tgt  \
# 0      1    22  DEN     D.Thomas        2010         22  10.0   2.0   39.0
# 1      1    24  DAL     D.Bryant        2010         21  12.0   2.0   73.0
# 2      2    36  KAN  D.McCluster        2010         21  11.0   7.0   39.0
# 3      2    39  TAM       A.Benn        2010         21  15.0   9.0   38.0
# 4      2    60  SEA       G.Tate        2010         22  11.0   0.0   39.0
# ..   ...   ...  ...          ...         ...        ...   ...   ...    ...
# 101    2    62  ARI   A.Isabella        2019         22  15.0   1.0   13.0
# 102    2    64  SEA    D.Metcalf        2019         21  16.0  15.0  100.0
# 103    3    66  PIT    D.Johnson        2019         23  16.0  12.0   92.0
# 104    3    76  WAS   T.McLaurin        2019         23  14.0  14.0   93.0
# 105    3    93  BAL     M.Boykin        2019         22  16.0  11.0   22.0
#
# ...
